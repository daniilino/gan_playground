# %%
import os

import torch
import torch.nn as nn
from torchvision.datasets import ImageFolder

import cv2

from model_arch import TwoPicsGenerator, LitTwoPicsGenerator, VanillaGAN, IdentityBlock, LitGAN
from losses import LossForGenerator, LossForDiscriminator
from dataset import LitImageFolderDataModule

import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger

from demo_utils import interpolate_two_points, normalize_image

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\Users\Admin\Anaconda3\envs\vcr_logo\lib\site-packages\torchaudio\backend\utils.py:74: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")

# %%
HEIGHT = 32
WIDTH = 32
LOG_FOLDER_NAME = "lightning_logs"
EXPERIMENT_NAME = "vanilla_gan"
dataset_folder = r"data\mnist"

datamodule = LitImageFolderDataModule(dataset_folder)
datamodule.setup(HEIGHT, WIDTH, data_mean=[0.1318], data_std=[0.2812], num_workers=4)

# %%
emb_size = 3
model_gan = VanillaGAN(emb_size, datamodule.transforms, img_hw=(HEIGHT, WIDTH))

loss_G_fx = LossForGenerator()
loss_D_fx = LossForDiscriminator()

gan = LitGAN(model_gan, loss_G_fx, loss_D_fx, experiment_name=EXPERIMENT_NAME)
# Out:
# generator_intermediate_hws: tensor([[ 4,  4],
#         [ 8,  8],
#         [16, 16],
#         [32, 32]], dtype=torch.int32)

# %%
checkpoint_callback = pl.callbacks.ModelCheckpoint(
    save_top_k=3,
    verbose=True,
    monitor='epoch',
    mode='max',
    dirpath=os.path.join(LOG_FOLDER_NAME, gan.experiment_name)
)

logger = TensorBoardLogger(LOG_FOLDER_NAME, name=gan.experiment_name)
gan.enable_scheduler = False
gan.lr = 1e-5
gan.l2reg = 1e-9

# CKPT_NAME = "epoch=23-step=10752.ckpt"
# CKPT_PATH = os.path.join(LOG_FOLDER_NAME, gan.experiment_name, CKPT_NAME)

trainer = pl.Trainer(max_epochs=1000, callbacks=[checkpoint_callback], logger=logger)
trainer.fit(gan, train_dataloaders=datamodule.dataloader, 
            val_dataloaders=datamodule.dataloader)#, ckpt_path = CKPT_PATH)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type                 | Params
# ---------------------------------------------------
# 0 | model     | VanillaGAN           | 28.2 K
# 1 | loss_G_fx | LossForGenerator     | 0
# 2 | loss_D_fx | LossForDiscriminator | 0
# ---------------------------------------------------
# 28.2 K    Trainable params
# 0         Non-trainable params
# 28.2 K    Total params
# 0.113     Total estimated model params size (MB)
# CURRENT VERSION: 10
# Training: 0it [00:00, ?it/s]
# Epoch 0, global step 448: 'epoch' reached 0.00000 (best 0.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=0-step=448.ckpt' as top 3
# Epoch 1, global step 896: 'epoch' reached 1.00000 (best 1.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=1-step=896.ckpt' as top 3
# Epoch 2, global step 1344: 'epoch' reached 2.00000 (best 2.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=2-step=1344.ckpt' as top 3
# Epoch 3, global step 1792: 'epoch' reached 3.00000 (best 3.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=3-step=1792.ckpt' as top 3
# Epoch 4, global step 2240: 'epoch' reached 4.00000 (best 4.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=4-step=2240.ckpt' as top 3
# Epoch 5, global step 2688: 'epoch' reached 5.00000 (best 5.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=5-step=2688.ckpt' as top 3
# Epoch 6, global step 3136: 'epoch' reached 6.00000 (best 6.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=6-step=3136.ckpt' as top 3
# Epoch 7, global step 3584: 'epoch' reached 7.00000 (best 7.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=7-step=3584.ckpt' as top 3
# Epoch 8, global step 4032: 'epoch' reached 8.00000 (best 8.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=8-step=4032.ckpt' as top 3
# Epoch 9, global step 4480: 'epoch' reached 9.00000 (best 9.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=9-step=4480-v1.ckpt' as top 3
# Epoch 10, global step 4928: 'epoch' reached 10.00000 (best 10.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=10-step=4928-v1.ckpt' as top 3
# Epoch 11, global step 5376: 'epoch' reached 11.00000 (best 11.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=11-step=5376-v1.ckpt' as top 3
# Epoch 12, global step 5824: 'epoch' reached 12.00000 (best 12.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=12-step=5824.ckpt' as top 3
# Epoch 13, global step 6272: 'epoch' reached 13.00000 (best 13.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=13-step=6272.ckpt' as top 3
# Epoch 14, global step 6720: 'epoch' reached 14.00000 (best 14.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=14-step=6720.ckpt' as top 3
# Epoch 15, global step 7168: 'epoch' reached 15.00000 (best 15.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=15-step=7168.ckpt' as top 3
# Epoch 16, global step 7616: 'epoch' reached 16.00000 (best 16.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=16-step=7616.ckpt' as top 3
# Epoch 17, global step 8064: 'epoch' reached 17.00000 (best 17.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=17-step=8064.ckpt' as top 3
# Epoch 18, global step 8512: 'epoch' reached 18.00000 (best 18.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=18-step=8512.ckpt' as top 3
# Epoch 19, global step 8960: 'epoch' reached 19.00000 (best 19.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=19-step=8960.ckpt' as top 3
# Epoch 20, global step 9408: 'epoch' reached 20.00000 (best 20.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=20-step=9408.ckpt' as top 3
# Epoch 21, global step 9856: 'epoch' reached 21.00000 (best 21.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=21-step=9856.ckpt' as top 3
# Epoch 22, global step 10304: 'epoch' reached 22.00000 (best 22.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=22-step=10304.ckpt' as top 3
# Epoch 23, global step 10752: 'epoch' reached 23.00000 (best 23.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=23-step=10752.ckpt' as top 3
# Epoch 24, global step 11200: 'epoch' reached 24.00000 (best 24.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=24-step=11200.ckpt' as top 3
# Epoch 25, global step 11648: 'epoch' reached 25.00000 (best 25.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=25-step=11648.ckpt' as top 3
# Epoch 26, global step 12096: 'epoch' reached 26.00000 (best 26.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=26-step=12096.ckpt' as top 3
# Epoch 27, global step 12544: 'epoch' reached 27.00000 (best 27.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=27-step=12544-v1.ckpt' as top 3
# Epoch 28, global step 12992: 'epoch' reached 28.00000 (best 28.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=28-step=12992-v1.ckpt' as top 3
# Epoch 29, global step 13440: 'epoch' reached 29.00000 (best 29.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=29-step=13440-v1.ckpt' as top 3
# Epoch 30, global step 13888: 'epoch' reached 30.00000 (best 30.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=30-step=13888.ckpt' as top 3
# Epoch 31, global step 14336: 'epoch' reached 31.00000 (best 31.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=31-step=14336.ckpt' as top 3
# Epoch 32, global step 14784: 'epoch' reached 32.00000 (best 32.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=32-step=14784.ckpt' as top 3
# Epoch 33, global step 15232: 'epoch' reached 33.00000 (best 33.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=33-step=15232.ckpt' as top 3
# Epoch 34, global step 15680: 'epoch' reached 34.00000 (best 34.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=34-step=15680.ckpt' as top 3
# Epoch 35, global step 16128: 'epoch' reached 35.00000 (best 35.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=35-step=16128.ckpt' as top 3
# Epoch 36, global step 16576: 'epoch' reached 36.00000 (best 36.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=36-step=16576.ckpt' as top 3
# Epoch 37, global step 17024: 'epoch' reached 37.00000 (best 37.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=37-step=17024.ckpt' as top 3
# Epoch 38, global step 17472: 'epoch' reached 38.00000 (best 38.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=38-step=17472.ckpt' as top 3
# Epoch 39, global step 17920: 'epoch' reached 39.00000 (best 39.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=39-step=17920.ckpt' as top 3
# Epoch 40, global step 18368: 'epoch' reached 40.00000 (best 40.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=40-step=18368.ckpt' as top 3
# Epoch 41, global step 18816: 'epoch' reached 41.00000 (best 41.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=41-step=18816.ckpt' as top 3
# Epoch 42, global step 19264: 'epoch' reached 42.00000 (best 42.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=42-step=19264.ckpt' as top 3
# Epoch 43, global step 19712: 'epoch' reached 43.00000 (best 43.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=43-step=19712.ckpt' as top 3
# Epoch 44, global step 20160: 'epoch' reached 44.00000 (best 44.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=44-step=20160.ckpt' as top 3
# Epoch 45, global step 20608: 'epoch' reached 45.00000 (best 45.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=45-step=20608.ckpt' as top 3
# Epoch 46, global step 21056: 'epoch' reached 46.00000 (best 46.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=46-step=21056.ckpt' as top 3
# Epoch 47, global step 21504: 'epoch' reached 47.00000 (best 47.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=47-step=21504.ckpt' as top 3
# Epoch 48, global step 21952: 'epoch' reached 48.00000 (best 48.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=48-step=21952.ckpt' as top 3
# Epoch 49, global step 22400: 'epoch' reached 49.00000 (best 49.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=49-step=22400.ckpt' as top 3
# Epoch 50, global step 22848: 'epoch' reached 50.00000 (best 50.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=50-step=22848.ckpt' as top 3
# Epoch 51, global step 23296: 'epoch' reached 51.00000 (best 51.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=51-step=23296.ckpt' as top 3
# Epoch 52, global step 23744: 'epoch' reached 52.00000 (best 52.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=52-step=23744.ckpt' as top 3
# Epoch 53, global step 24192: 'epoch' reached 53.00000 (best 53.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=53-step=24192.ckpt' as top 3
# Epoch 54, global step 24640: 'epoch' reached 54.00000 (best 54.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=54-step=24640.ckpt' as top 3
# Epoch 55, global step 25088: 'epoch' reached 55.00000 (best 55.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=55-step=25088.ckpt' as top 3
# Epoch 56, global step 25536: 'epoch' reached 56.00000 (best 56.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=56-step=25536.ckpt' as top 3
# Epoch 57, global step 25984: 'epoch' reached 57.00000 (best 57.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=57-step=25984.ckpt' as top 3
# Epoch 58, global step 26432: 'epoch' reached 58.00000 (best 58.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=58-step=26432.ckpt' as top 3
# Epoch 59, global step 26880: 'epoch' reached 59.00000 (best 59.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=59-step=26880.ckpt' as top 3
# Epoch 60, global step 27328: 'epoch' reached 60.00000 (best 60.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=60-step=27328.ckpt' as top 3
# Epoch 61, global step 27776: 'epoch' reached 61.00000 (best 61.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=61-step=27776.ckpt' as top 3
# Epoch 62, global step 28224: 'epoch' reached 62.00000 (best 62.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=62-step=28224.ckpt' as top 3
# Epoch 63, global step 28672: 'epoch' reached 63.00000 (best 63.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=63-step=28672.ckpt' as top 3
# Epoch 64, global step 29120: 'epoch' reached 64.00000 (best 64.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=64-step=29120.ckpt' as top 3
# Epoch 65, global step 29568: 'epoch' reached 65.00000 (best 65.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=65-step=29568.ckpt' as top 3
# Epoch 66, global step 30016: 'epoch' reached 66.00000 (best 66.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=66-step=30016.ckpt' as top 3
# Epoch 67, global step 30464: 'epoch' reached 67.00000 (best 67.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=67-step=30464.ckpt' as top 3
# Epoch 68, global step 30912: 'epoch' reached 68.00000 (best 68.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=68-step=30912.ckpt' as top 3
# Epoch 69, global step 31360: 'epoch' reached 69.00000 (best 69.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=69-step=31360.ckpt' as top 3
# Epoch 70, global step 31808: 'epoch' reached 70.00000 (best 70.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=70-step=31808.ckpt' as top 3
# Epoch 71, global step 32256: 'epoch' reached 71.00000 (best 71.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=71-step=32256.ckpt' as top 3
# Epoch 72, global step 32704: 'epoch' reached 72.00000 (best 72.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=72-step=32704.ckpt' as top 3
# Epoch 73, global step 33152: 'epoch' reached 73.00000 (best 73.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=73-step=33152.ckpt' as top 3
# Epoch 74, global step 33600: 'epoch' reached 74.00000 (best 74.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=74-step=33600.ckpt' as top 3
# Epoch 75, global step 34048: 'epoch' reached 75.00000 (best 75.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=75-step=34048.ckpt' as top 3
# Epoch 76, global step 34496: 'epoch' reached 76.00000 (best 76.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=76-step=34496.ckpt' as top 3
# Epoch 77, global step 34944: 'epoch' reached 77.00000 (best 77.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=77-step=34944.ckpt' as top 3
# Epoch 78, global step 35392: 'epoch' reached 78.00000 (best 78.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=78-step=35392.ckpt' as top 3
# Epoch 79, global step 35840: 'epoch' reached 79.00000 (best 79.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=79-step=35840.ckpt' as top 3
# Epoch 80, global step 36288: 'epoch' reached 80.00000 (best 80.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=80-step=36288.ckpt' as top 3
# Epoch 81, global step 36736: 'epoch' reached 81.00000 (best 81.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=81-step=36736.ckpt' as top 3
# Epoch 82, global step 37184: 'epoch' reached 82.00000 (best 82.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=82-step=37184.ckpt' as top 3
# Epoch 83, global step 37632: 'epoch' reached 83.00000 (best 83.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=83-step=37632.ckpt' as top 3
# Epoch 84, global step 38080: 'epoch' reached 84.00000 (best 84.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=84-step=38080.ckpt' as top 3
# Epoch 85, global step 38528: 'epoch' reached 85.00000 (best 85.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=85-step=38528.ckpt' as top 3
# Epoch 86, global step 38976: 'epoch' reached 86.00000 (best 86.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=86-step=38976.ckpt' as top 3
# Epoch 87, global step 39424: 'epoch' reached 87.00000 (best 87.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=87-step=39424.ckpt' as top 3
# Epoch 88, global step 39872: 'epoch' reached 88.00000 (best 88.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=88-step=39872.ckpt' as top 3
# Epoch 89, global step 40320: 'epoch' reached 89.00000 (best 89.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=89-step=40320.ckpt' as top 3
# Epoch 90, global step 40768: 'epoch' reached 90.00000 (best 90.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=90-step=40768.ckpt' as top 3
# Epoch 91, global step 41216: 'epoch' reached 91.00000 (best 91.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=91-step=41216.ckpt' as top 3
# Epoch 92, global step 41664: 'epoch' reached 92.00000 (best 92.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=92-step=41664.ckpt' as top 3
# Epoch 93, global step 42112: 'epoch' reached 93.00000 (best 93.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=93-step=42112.ckpt' as top 3
# Epoch 94, global step 42560: 'epoch' reached 94.00000 (best 94.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=94-step=42560.ckpt' as top 3
# Epoch 95, global step 43008: 'epoch' reached 95.00000 (best 95.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=95-step=43008.ckpt' as top 3
# Epoch 96, global step 43456: 'epoch' reached 96.00000 (best 96.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=96-step=43456.ckpt' as top 3
# Epoch 97, global step 43904: 'epoch' reached 97.00000 (best 97.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=97-step=43904.ckpt' as top 3
# Epoch 98, global step 44352: 'epoch' reached 98.00000 (best 98.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=98-step=44352.ckpt' as top 3
# Epoch 99, global step 44800: 'epoch' reached 99.00000 (best 99.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=99-step=44800.ckpt' as top 3
# Epoch 100, global step 45248: 'epoch' reached 100.00000 (best 100.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=100-step=45248.ckpt' as top 3
# Epoch 101, global step 45696: 'epoch' reached 101.00000 (best 101.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=101-step=45696.ckpt' as top 3
# Epoch 102, global step 46144: 'epoch' reached 102.00000 (best 102.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=102-step=46144.ckpt' as top 3
# Epoch 103, global step 46592: 'epoch' reached 103.00000 (best 103.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=103-step=46592.ckpt' as top 3
# Epoch 104, global step 47040: 'epoch' reached 104.00000 (best 104.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=104-step=47040.ckpt' as top 3
# Epoch 105, global step 47488: 'epoch' reached 105.00000 (best 105.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=105-step=47488.ckpt' as top 3
# Epoch 106, global step 47936: 'epoch' reached 106.00000 (best 106.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=106-step=47936.ckpt' as top 3
# Epoch 107, global step 48384: 'epoch' reached 107.00000 (best 107.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=107-step=48384.ckpt' as top 3
# Epoch 108, global step 48832: 'epoch' reached 108.00000 (best 108.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=108-step=48832.ckpt' as top 3
# Epoch 109, global step 49280: 'epoch' reached 109.00000 (best 109.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=109-step=49280.ckpt' as top 3
# Epoch 110, global step 49728: 'epoch' reached 110.00000 (best 110.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=110-step=49728.ckpt' as top 3
# Epoch 111, global step 50176: 'epoch' reached 111.00000 (best 111.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=111-step=50176.ckpt' as top 3
# Epoch 112, global step 50624: 'epoch' reached 112.00000 (best 112.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=112-step=50624.ckpt' as top 3
# Epoch 113, global step 51072: 'epoch' reached 113.00000 (best 113.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=113-step=51072.ckpt' as top 3
# Epoch 114, global step 51520: 'epoch' reached 114.00000 (best 114.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=114-step=51520.ckpt' as top 3
# Epoch 115, global step 51968: 'epoch' reached 115.00000 (best 115.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=115-step=51968.ckpt' as top 3
# Epoch 116, global step 52416: 'epoch' reached 116.00000 (best 116.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=116-step=52416.ckpt' as top 3
# Epoch 117, global step 52864: 'epoch' reached 117.00000 (best 117.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=117-step=52864.ckpt' as top 3
# Epoch 118, global step 53312: 'epoch' reached 118.00000 (best 118.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=118-step=53312.ckpt' as top 3
# Epoch 119, global step 53760: 'epoch' reached 119.00000 (best 119.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=119-step=53760.ckpt' as top 3
# Epoch 120, global step 54208: 'epoch' reached 120.00000 (best 120.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=120-step=54208.ckpt' as top 3
# Epoch 121, global step 54656: 'epoch' reached 121.00000 (best 121.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=121-step=54656.ckpt' as top 3
# Epoch 122, global step 55104: 'epoch' reached 122.00000 (best 122.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=122-step=55104.ckpt' as top 3
# Epoch 123, global step 55552: 'epoch' reached 123.00000 (best 123.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=123-step=55552.ckpt' as top 3
# Epoch 124, global step 56000: 'epoch' reached 124.00000 (best 124.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=124-step=56000.ckpt' as top 3
# Epoch 125, global step 56448: 'epoch' reached 125.00000 (best 125.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=125-step=56448.ckpt' as top 3
# Epoch 126, global step 56896: 'epoch' reached 126.00000 (best 126.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=126-step=56896.ckpt' as top 3
# Epoch 127, global step 57344: 'epoch' reached 127.00000 (best 127.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=127-step=57344.ckpt' as top 3
# Epoch 128, global step 57792: 'epoch' reached 128.00000 (best 128.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=128-step=57792.ckpt' as top 3
# Epoch 129, global step 58240: 'epoch' reached 129.00000 (best 129.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=129-step=58240.ckpt' as top 3
# Epoch 130, global step 58688: 'epoch' reached 130.00000 (best 130.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=130-step=58688.ckpt' as top 3
# Epoch 131, global step 59136: 'epoch' reached 131.00000 (best 131.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=131-step=59136.ckpt' as top 3
# Epoch 132, global step 59584: 'epoch' reached 132.00000 (best 132.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=132-step=59584.ckpt' as top 3
# Epoch 133, global step 60032: 'epoch' reached 133.00000 (best 133.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=133-step=60032.ckpt' as top 3
# Epoch 134, global step 60480: 'epoch' reached 134.00000 (best 134.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=134-step=60480.ckpt' as top 3
# Epoch 135, global step 60928: 'epoch' reached 135.00000 (best 135.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=135-step=60928.ckpt' as top 3
# Epoch 136, global step 61376: 'epoch' reached 136.00000 (best 136.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=136-step=61376.ckpt' as top 3
# Epoch 137, global step 61824: 'epoch' reached 137.00000 (best 137.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=137-step=61824.ckpt' as top 3
# Epoch 138, global step 62272: 'epoch' reached 138.00000 (best 138.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=138-step=62272.ckpt' as top 3
# Epoch 139, global step 62720: 'epoch' reached 139.00000 (best 139.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=139-step=62720.ckpt' as top 3
# Epoch 140, global step 63168: 'epoch' reached 140.00000 (best 140.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=140-step=63168.ckpt' as top 3
# Epoch 141, global step 63616: 'epoch' reached 141.00000 (best 141.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=141-step=63616.ckpt' as top 3
# Epoch 142, global step 64064: 'epoch' reached 142.00000 (best 142.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=142-step=64064.ckpt' as top 3
# Epoch 143, global step 64512: 'epoch' reached 143.00000 (best 143.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=143-step=64512.ckpt' as top 3
# Epoch 144, global step 64960: 'epoch' reached 144.00000 (best 144.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=144-step=64960.ckpt' as top 3
# Epoch 145, global step 65408: 'epoch' reached 145.00000 (best 145.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=145-step=65408.ckpt' as top 3
# Epoch 146, global step 65856: 'epoch' reached 146.00000 (best 146.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=146-step=65856.ckpt' as top 3
# Epoch 147, global step 66304: 'epoch' reached 147.00000 (best 147.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=147-step=66304.ckpt' as top 3
# Epoch 148, global step 66752: 'epoch' reached 148.00000 (best 148.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=148-step=66752.ckpt' as top 3
# Epoch 149, global step 67200: 'epoch' reached 149.00000 (best 149.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=149-step=67200.ckpt' as top 3
# Epoch 150, global step 67648: 'epoch' reached 150.00000 (best 150.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=150-step=67648.ckpt' as top 3
# Epoch 151, global step 68096: 'epoch' reached 151.00000 (best 151.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=151-step=68096.ckpt' as top 3
# Epoch 152, global step 68544: 'epoch' reached 152.00000 (best 152.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=152-step=68544.ckpt' as top 3
# Epoch 153, global step 68992: 'epoch' reached 153.00000 (best 153.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=153-step=68992.ckpt' as top 3
# Epoch 154, global step 69440: 'epoch' reached 154.00000 (best 154.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=154-step=69440.ckpt' as top 3
# Epoch 155, global step 69888: 'epoch' reached 155.00000 (best 155.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=155-step=69888.ckpt' as top 3
# Epoch 156, global step 70336: 'epoch' reached 156.00000 (best 156.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=156-step=70336.ckpt' as top 3
# Epoch 157, global step 70784: 'epoch' reached 157.00000 (best 157.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=157-step=70784.ckpt' as top 3
# Epoch 158, global step 71232: 'epoch' reached 158.00000 (best 158.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=158-step=71232.ckpt' as top 3
# Epoch 159, global step 71680: 'epoch' reached 159.00000 (best 159.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=159-step=71680.ckpt' as top 3
# Epoch 160, global step 72128: 'epoch' reached 160.00000 (best 160.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=160-step=72128.ckpt' as top 3
# Epoch 161, global step 72576: 'epoch' reached 161.00000 (best 161.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=161-step=72576.ckpt' as top 3
# Epoch 162, global step 73024: 'epoch' reached 162.00000 (best 162.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=162-step=73024.ckpt' as top 3
# Epoch 163, global step 73472: 'epoch' reached 163.00000 (best 163.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=163-step=73472.ckpt' as top 3
# Epoch 164, global step 73920: 'epoch' reached 164.00000 (best 164.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=164-step=73920.ckpt' as top 3
# Epoch 165, global step 74368: 'epoch' reached 165.00000 (best 165.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=165-step=74368.ckpt' as top 3
# Epoch 166, global step 74816: 'epoch' reached 166.00000 (best 166.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=166-step=74816.ckpt' as top 3
# Epoch 167, global step 75264: 'epoch' reached 167.00000 (best 167.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=167-step=75264-v1.ckpt' as top 3
# Epoch 168, global step 75712: 'epoch' reached 168.00000 (best 168.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=168-step=75712-v1.ckpt' as top 3
# Epoch 169, global step 76160: 'epoch' reached 169.00000 (best 169.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=169-step=76160-v1.ckpt' as top 3
# Epoch 170, global step 76608: 'epoch' reached 170.00000 (best 170.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=170-step=76608.ckpt' as top 3
# Epoch 171, global step 77056: 'epoch' reached 171.00000 (best 171.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=171-step=77056.ckpt' as top 3
# Epoch 172, global step 77504: 'epoch' reached 172.00000 (best 172.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=172-step=77504.ckpt' as top 3
# Epoch 173, global step 77952: 'epoch' reached 173.00000 (best 173.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=173-step=77952.ckpt' as top 3
# Epoch 174, global step 78400: 'epoch' reached 174.00000 (best 174.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=174-step=78400.ckpt' as top 3
# Epoch 175, global step 78848: 'epoch' reached 175.00000 (best 175.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=175-step=78848.ckpt' as top 3
# Epoch 176, global step 79296: 'epoch' reached 176.00000 (best 176.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=176-step=79296.ckpt' as top 3
# Epoch 177, global step 79744: 'epoch' reached 177.00000 (best 177.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=177-step=79744.ckpt' as top 3
# Epoch 178, global step 80192: 'epoch' reached 178.00000 (best 178.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=178-step=80192.ckpt' as top 3
# Epoch 179, global step 80640: 'epoch' reached 179.00000 (best 179.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=179-step=80640.ckpt' as top 3
# Epoch 180, global step 81088: 'epoch' reached 180.00000 (best 180.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=180-step=81088.ckpt' as top 3
# Epoch 181, global step 81536: 'epoch' reached 181.00000 (best 181.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=181-step=81536.ckpt' as top 3
# Epoch 182, global step 81984: 'epoch' reached 182.00000 (best 182.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=182-step=81984.ckpt' as top 3
# Epoch 183, global step 82432: 'epoch' reached 183.00000 (best 183.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=183-step=82432.ckpt' as top 3
# Epoch 184, global step 82880: 'epoch' reached 184.00000 (best 184.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=184-step=82880.ckpt' as top 3
# Epoch 185, global step 83328: 'epoch' reached 185.00000 (best 185.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=185-step=83328.ckpt' as top 3
# Epoch 186, global step 83776: 'epoch' reached 186.00000 (best 186.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=186-step=83776.ckpt' as top 3
# Epoch 187, global step 84224: 'epoch' reached 187.00000 (best 187.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=187-step=84224.ckpt' as top 3
# Epoch 188, global step 84672: 'epoch' reached 188.00000 (best 188.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=188-step=84672.ckpt' as top 3
# Epoch 189, global step 85120: 'epoch' reached 189.00000 (best 189.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=189-step=85120.ckpt' as top 3
# Epoch 190, global step 85568: 'epoch' reached 190.00000 (best 190.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=190-step=85568.ckpt' as top 3
# Epoch 191, global step 86016: 'epoch' reached 191.00000 (best 191.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=191-step=86016.ckpt' as top 3
# Epoch 192, global step 86464: 'epoch' reached 192.00000 (best 192.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=192-step=86464.ckpt' as top 3
# Epoch 193, global step 86912: 'epoch' reached 193.00000 (best 193.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=193-step=86912.ckpt' as top 3
# Epoch 194, global step 87360: 'epoch' reached 194.00000 (best 194.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=194-step=87360.ckpt' as top 3
# Epoch 195, global step 87808: 'epoch' reached 195.00000 (best 195.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=195-step=87808.ckpt' as top 3
# Epoch 196, global step 88256: 'epoch' reached 196.00000 (best 196.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=196-step=88256.ckpt' as top 3
# Epoch 197, global step 88704: 'epoch' reached 197.00000 (best 197.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=197-step=88704.ckpt' as top 3
# Epoch 198, global step 89152: 'epoch' reached 198.00000 (best 198.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=198-step=89152.ckpt' as top 3
# Epoch 199, global step 89600: 'epoch' reached 199.00000 (best 199.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=199-step=89600.ckpt' as top 3
# Epoch 200, global step 90048: 'epoch' reached 200.00000 (best 200.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=200-step=90048.ckpt' as top 3
# Epoch 201, global step 90496: 'epoch' reached 201.00000 (best 201.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=201-step=90496.ckpt' as top 3
# Epoch 202, global step 90944: 'epoch' reached 202.00000 (best 202.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=202-step=90944.ckpt' as top 3
# Epoch 203, global step 91392: 'epoch' reached 203.00000 (best 203.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=203-step=91392-v1.ckpt' as top 3
# Epoch 204, global step 91840: 'epoch' reached 204.00000 (best 204.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=204-step=91840-v1.ckpt' as top 3
# Epoch 205, global step 92288: 'epoch' reached 205.00000 (best 205.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=205-step=92288-v1.ckpt' as top 3
# Epoch 206, global step 92736: 'epoch' reached 206.00000 (best 206.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=206-step=92736.ckpt' as top 3
# Epoch 207, global step 93184: 'epoch' reached 207.00000 (best 207.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=207-step=93184.ckpt' as top 3
# Epoch 208, global step 93632: 'epoch' reached 208.00000 (best 208.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=208-step=93632.ckpt' as top 3
# Epoch 209, global step 94080: 'epoch' reached 209.00000 (best 209.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=209-step=94080.ckpt' as top 3
# Epoch 210, global step 94528: 'epoch' reached 210.00000 (best 210.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=210-step=94528.ckpt' as top 3
# Epoch 211, global step 94976: 'epoch' reached 211.00000 (best 211.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=211-step=94976.ckpt' as top 3
# Epoch 212, global step 95424: 'epoch' reached 212.00000 (best 212.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=212-step=95424.ckpt' as top 3
# Epoch 213, global step 95872: 'epoch' reached 213.00000 (best 213.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=213-step=95872.ckpt' as top 3
# Epoch 214, global step 96320: 'epoch' reached 214.00000 (best 214.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=214-step=96320.ckpt' as top 3
# Epoch 215, global step 96768: 'epoch' reached 215.00000 (best 215.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=215-step=96768.ckpt' as top 3
# Epoch 216, global step 97216: 'epoch' reached 216.00000 (best 216.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=216-step=97216.ckpt' as top 3
# Epoch 217, global step 97664: 'epoch' reached 217.00000 (best 217.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=217-step=97664.ckpt' as top 3
# Epoch 218, global step 98112: 'epoch' reached 218.00000 (best 218.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=218-step=98112.ckpt' as top 3
# Epoch 219, global step 98560: 'epoch' reached 219.00000 (best 219.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=219-step=98560.ckpt' as top 3
# Epoch 220, global step 99008: 'epoch' reached 220.00000 (best 220.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=220-step=99008.ckpt' as top 3
# Epoch 221, global step 99456: 'epoch' reached 221.00000 (best 221.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=221-step=99456.ckpt' as top 3
# Epoch 222, global step 99904: 'epoch' reached 222.00000 (best 222.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=222-step=99904.ckpt' as top 3
# Epoch 223, global step 100352: 'epoch' reached 223.00000 (best 223.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=223-step=100352.ckpt' as top 3
# Epoch 224, global step 100800: 'epoch' reached 224.00000 (best 224.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=224-step=100800.ckpt' as top 3
# Epoch 225, global step 101248: 'epoch' reached 225.00000 (best 225.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=225-step=101248.ckpt' as top 3
# Epoch 226, global step 101696: 'epoch' reached 226.00000 (best 226.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=226-step=101696.ckpt' as top 3
# Epoch 227, global step 102144: 'epoch' reached 227.00000 (best 227.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=227-step=102144.ckpt' as top 3
# Epoch 228, global step 102592: 'epoch' reached 228.00000 (best 228.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=228-step=102592.ckpt' as top 3
# Epoch 229, global step 103040: 'epoch' reached 229.00000 (best 229.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=229-step=103040.ckpt' as top 3
# Epoch 230, global step 103488: 'epoch' reached 230.00000 (best 230.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=230-step=103488.ckpt' as top 3
# Epoch 231, global step 103936: 'epoch' reached 231.00000 (best 231.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=231-step=103936.ckpt' as top 3
# Epoch 232, global step 104384: 'epoch' reached 232.00000 (best 232.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=232-step=104384.ckpt' as top 3
# Epoch 233, global step 104832: 'epoch' reached 233.00000 (best 233.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=233-step=104832.ckpt' as top 3
# Epoch 234, global step 105280: 'epoch' reached 234.00000 (best 234.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=234-step=105280.ckpt' as top 3
# Epoch 235, global step 105728: 'epoch' reached 235.00000 (best 235.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=235-step=105728.ckpt' as top 3
# Epoch 236, global step 106176: 'epoch' reached 236.00000 (best 236.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=236-step=106176.ckpt' as top 3
# Epoch 237, global step 106624: 'epoch' reached 237.00000 (best 237.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=237-step=106624.ckpt' as top 3
# Epoch 238, global step 107072: 'epoch' reached 238.00000 (best 238.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=238-step=107072.ckpt' as top 3
# Epoch 239, global step 107520: 'epoch' reached 239.00000 (best 239.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=239-step=107520.ckpt' as top 3
# Epoch 240, global step 107968: 'epoch' reached 240.00000 (best 240.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=240-step=107968.ckpt' as top 3
# Epoch 241, global step 108416: 'epoch' reached 241.00000 (best 241.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=241-step=108416.ckpt' as top 3
# Epoch 242, global step 108864: 'epoch' reached 242.00000 (best 242.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=242-step=108864.ckpt' as top 3
# ...
# Epoch 920, global step 412608: 'epoch' reached 920.00000 (best 920.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=920-step=412608.ckpt' as top 3
# Epoch 921, global step 413056: 'epoch' reached 921.00000 (best 921.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=921-step=413056.ckpt' as top 3
# Epoch 922, global step 413504: 'epoch' reached 922.00000 (best 922.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=922-step=413504.ckpt' as top 3
# Epoch 923, global step 413952: 'epoch' reached 923.00000 (best 923.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=923-step=413952.ckpt' as top 3
# Epoch 924, global step 414400: 'epoch' reached 924.00000 (best 924.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=924-step=414400.ckpt' as top 3
# Epoch 925, global step 414848: 'epoch' reached 925.00000 (best 925.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=925-step=414848.ckpt' as top 3
# Epoch 926, global step 415296: 'epoch' reached 926.00000 (best 926.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=926-step=415296.ckpt' as top 3
# Epoch 927, global step 415744: 'epoch' reached 927.00000 (best 927.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=927-step=415744.ckpt' as top 3
# Epoch 928, global step 416192: 'epoch' reached 928.00000 (best 928.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=928-step=416192.ckpt' as top 3
# Epoch 929, global step 416640: 'epoch' reached 929.00000 (best 929.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=929-step=416640.ckpt' as top 3
# Epoch 930, global step 417088: 'epoch' reached 930.00000 (best 930.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=930-step=417088.ckpt' as top 3
# Epoch 931, global step 417536: 'epoch' reached 931.00000 (best 931.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=931-step=417536.ckpt' as top 3
# Epoch 932, global step 417984: 'epoch' reached 932.00000 (best 932.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=932-step=417984.ckpt' as top 3
# Epoch 933, global step 418432: 'epoch' reached 933.00000 (best 933.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=933-step=418432.ckpt' as top 3
# Epoch 934, global step 418880: 'epoch' reached 934.00000 (best 934.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=934-step=418880.ckpt' as top 3
# Epoch 935, global step 419328: 'epoch' reached 935.00000 (best 935.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=935-step=419328.ckpt' as top 3
# Epoch 936, global step 419776: 'epoch' reached 936.00000 (best 936.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=936-step=419776.ckpt' as top 3
# Epoch 937, global step 420224: 'epoch' reached 937.00000 (best 937.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=937-step=420224.ckpt' as top 3
# Epoch 938, global step 420672: 'epoch' reached 938.00000 (best 938.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=938-step=420672.ckpt' as top 3
# Epoch 939, global step 421120: 'epoch' reached 939.00000 (best 939.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=939-step=421120.ckpt' as top 3
# Epoch 940, global step 421568: 'epoch' reached 940.00000 (best 940.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=940-step=421568.ckpt' as top 3
# Epoch 941, global step 422016: 'epoch' reached 941.00000 (best 941.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=941-step=422016.ckpt' as top 3
# Epoch 942, global step 422464: 'epoch' reached 942.00000 (best 942.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=942-step=422464.ckpt' as top 3
# Epoch 943, global step 422912: 'epoch' reached 943.00000 (best 943.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=943-step=422912.ckpt' as top 3
# Epoch 944, global step 423360: 'epoch' reached 944.00000 (best 944.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=944-step=423360.ckpt' as top 3
# Epoch 945, global step 423808: 'epoch' reached 945.00000 (best 945.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=945-step=423808.ckpt' as top 3
# Epoch 946, global step 424256: 'epoch' reached 946.00000 (best 946.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=946-step=424256.ckpt' as top 3
# Epoch 947, global step 424704: 'epoch' reached 947.00000 (best 947.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=947-step=424704.ckpt' as top 3
# Epoch 948, global step 425152: 'epoch' reached 948.00000 (best 948.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=948-step=425152.ckpt' as top 3
# Epoch 949, global step 425600: 'epoch' reached 949.00000 (best 949.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=949-step=425600.ckpt' as top 3
# Epoch 950, global step 426048: 'epoch' reached 950.00000 (best 950.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=950-step=426048.ckpt' as top 3
# Epoch 951, global step 426496: 'epoch' reached 951.00000 (best 951.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=951-step=426496.ckpt' as top 3
# Epoch 952, global step 426944: 'epoch' reached 952.00000 (best 952.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=952-step=426944.ckpt' as top 3
# Epoch 953, global step 427392: 'epoch' reached 953.00000 (best 953.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=953-step=427392.ckpt' as top 3
# Epoch 954, global step 427840: 'epoch' reached 954.00000 (best 954.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=954-step=427840.ckpt' as top 3
# Epoch 955, global step 428288: 'epoch' reached 955.00000 (best 955.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=955-step=428288.ckpt' as top 3
# Epoch 956, global step 428736: 'epoch' reached 956.00000 (best 956.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=956-step=428736.ckpt' as top 3
# Epoch 957, global step 429184: 'epoch' reached 957.00000 (best 957.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=957-step=429184.ckpt' as top 3
# Epoch 958, global step 429632: 'epoch' reached 958.00000 (best 958.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=958-step=429632.ckpt' as top 3
# Epoch 959, global step 430080: 'epoch' reached 959.00000 (best 959.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=959-step=430080.ckpt' as top 3
# Epoch 960, global step 430528: 'epoch' reached 960.00000 (best 960.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=960-step=430528.ckpt' as top 3
# Epoch 961, global step 430976: 'epoch' reached 961.00000 (best 961.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=961-step=430976.ckpt' as top 3
# Epoch 962, global step 431424: 'epoch' reached 962.00000 (best 962.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=962-step=431424.ckpt' as top 3
# Epoch 963, global step 431872: 'epoch' reached 963.00000 (best 963.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=963-step=431872.ckpt' as top 3
# Epoch 964, global step 432320: 'epoch' reached 964.00000 (best 964.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=964-step=432320.ckpt' as top 3
# Epoch 965, global step 432768: 'epoch' reached 965.00000 (best 965.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=965-step=432768.ckpt' as top 3
# Epoch 966, global step 433216: 'epoch' reached 966.00000 (best 966.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=966-step=433216.ckpt' as top 3
# Epoch 967, global step 433664: 'epoch' reached 967.00000 (best 967.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=967-step=433664.ckpt' as top 3
# Epoch 968, global step 434112: 'epoch' reached 968.00000 (best 968.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=968-step=434112.ckpt' as top 3
# Epoch 969, global step 434560: 'epoch' reached 969.00000 (best 969.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=969-step=434560.ckpt' as top 3
# Epoch 970, global step 435008: 'epoch' reached 970.00000 (best 970.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=970-step=435008.ckpt' as top 3
# Epoch 971, global step 435456: 'epoch' reached 971.00000 (best 971.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=971-step=435456.ckpt' as top 3
# Epoch 972, global step 435904: 'epoch' reached 972.00000 (best 972.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=972-step=435904.ckpt' as top 3
# Epoch 973, global step 436352: 'epoch' reached 973.00000 (best 973.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=973-step=436352.ckpt' as top 3
# Epoch 974, global step 436800: 'epoch' reached 974.00000 (best 974.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=974-step=436800.ckpt' as top 3
# Epoch 975, global step 437248: 'epoch' reached 975.00000 (best 975.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=975-step=437248.ckpt' as top 3
# Epoch 976, global step 437696: 'epoch' reached 976.00000 (best 976.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=976-step=437696.ckpt' as top 3
# Epoch 977, global step 438144: 'epoch' reached 977.00000 (best 977.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=977-step=438144.ckpt' as top 3
# Epoch 978, global step 438592: 'epoch' reached 978.00000 (best 978.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=978-step=438592.ckpt' as top 3
# Epoch 979, global step 439040: 'epoch' reached 979.00000 (best 979.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=979-step=439040.ckpt' as top 3
# Epoch 980, global step 439488: 'epoch' reached 980.00000 (best 980.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=980-step=439488.ckpt' as top 3
# Epoch 981, global step 439936: 'epoch' reached 981.00000 (best 981.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=981-step=439936.ckpt' as top 3
# Epoch 982, global step 440384: 'epoch' reached 982.00000 (best 982.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=982-step=440384.ckpt' as top 3
# Epoch 983, global step 440832: 'epoch' reached 983.00000 (best 983.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=983-step=440832.ckpt' as top 3
# Epoch 984, global step 441280: 'epoch' reached 984.00000 (best 984.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=984-step=441280.ckpt' as top 3
# Epoch 985, global step 441728: 'epoch' reached 985.00000 (best 985.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=985-step=441728.ckpt' as top 3
# Epoch 986, global step 442176: 'epoch' reached 986.00000 (best 986.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=986-step=442176.ckpt' as top 3
# Epoch 987, global step 442624: 'epoch' reached 987.00000 (best 987.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=987-step=442624.ckpt' as top 3
# Epoch 988, global step 443072: 'epoch' reached 988.00000 (best 988.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=988-step=443072.ckpt' as top 3
# Epoch 989, global step 443520: 'epoch' reached 989.00000 (best 989.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=989-step=443520.ckpt' as top 3
# Epoch 990, global step 443968: 'epoch' reached 990.00000 (best 990.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=990-step=443968.ckpt' as top 3
# Epoch 991, global step 444416: 'epoch' reached 991.00000 (best 991.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=991-step=444416.ckpt' as top 3
# Epoch 992, global step 444864: 'epoch' reached 992.00000 (best 992.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=992-step=444864.ckpt' as top 3
# Epoch 993, global step 445312: 'epoch' reached 993.00000 (best 993.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=993-step=445312.ckpt' as top 3
# Epoch 994, global step 445760: 'epoch' reached 994.00000 (best 994.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=994-step=445760.ckpt' as top 3
# Epoch 995, global step 446208: 'epoch' reached 995.00000 (best 995.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=995-step=446208.ckpt' as top 3
# Epoch 996, global step 446656: 'epoch' reached 996.00000 (best 996.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=996-step=446656.ckpt' as top 3
# Epoch 997, global step 447104: 'epoch' reached 997.00000 (best 997.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=997-step=447104.ckpt' as top 3
# Epoch 998, global step 447552: 'epoch' reached 998.00000 (best 998.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=998-step=447552.ckpt' as top 3
# Epoch 999, global step 448000: 'epoch' reached 999.00000 (best 999.00000), saving model to 'C:\\Users\\Admin\\Desktop\\pic_sampler\\lightning_logs\\vanilla_gan\\epoch=999-step=448000.ckpt' as top 3
# `Trainer.fit` stopped: `max_epochs=1000` reached.

# %%
gan.model.eval()
with torch.no_grad():
    z = torch.randn(1, emb_size)
    print(z.shape)
    fake = gan.model.generate(z)
    print(fake.shape)

img = fake.cpu().numpy()[0,0,...]
img = normalize_image(img)/255
print(img.max(), img.min())

cv2.imshow("image", cv2.resize(img, (500, 500))) 
  
# waits for user to press any key 
# (this is necessary to avoid Python kernel form crashing) 
cv2.waitKey(0) 
  
# closing all open windows 
cv2.destroyAllWindows()
